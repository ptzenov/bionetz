# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

import holoviews as hv

# %%
data = pd.read_csv('measurement_records.csv')

# %%
data.describe()
# Out:
#         Unnamed: 0    CO2_value  Consumption_value  Engine_Load_value  \
# count  4900.000000  4809.000000        4200.000000        4695.000000
# mean     49.500000     2.499103           7.402362          19.940188
# std      28.869016     9.161109          13.038593         160.143164
# min       0.000000     0.000000           0.000000          -1.000000
# 25%      24.750000     0.000000           0.000000           0.000000
# 50%      49.500000     0.000000           0.001880           0.000000
# 75%      74.250000     0.000000          10.350380           0.000724
# max      99.000000   130.040000         121.087000        2312.000000
#
#        GPS_Accuracy_value  O2_Lambda_Voltage_ER_value  \
# count         4177.000000                  263.000000
# mean            58.998935                    0.909750
# std             43.486549                    0.271574
# min              0.000000                    0.000000
# 25%             27.000000                    0.982815
# ...

# %%
{col:len(data[col].isnull()) for col in data.columns}
# Out:
# {'CO2_unit': 4900,
#  'CO2_value': 4900,
#  'Consumption_unit': 4900,
#  'Consumption_value': 4900,
#  'Engine_Load_unit': 4900,
#  'Engine_Load_value': 4900,
#  'GPS_Accuracy_unit': 4900,
#  'GPS_Accuracy_value': 4900,
#  'GPS_Altitude_unit': 4900,
#  'GPS_Altitude_value': 4900,
#  'GPS_Bearing_unit': 4900,
#  'GPS_Bearing_value': 4900,
#  'GPS_HDOP_unit': 4900,
#  'GPS_HDOP_value': 4900,
#  'GPS_PDOP_unit': 4900,
#  'GPS_PDOP_value': 4900,
#  'GPS_Speed_unit': 4900,
#  'GPS_Speed_value': 4900,
#  'GPS_VDOP_unit': 4900,
#  'GPS_VDOP_value': 4900,
#  'Intake_Pressure_unit': 4900,
#  'Intake_Pressure_value': 4900,
#  'Intake_Temperature_unit': 4900,
#  'Intake_Temperature_value': 4900,
#  'MAF_unit': 4900,
#  'MAF_value': 4900,
#  'O2_Lambda_Voltage_ER_unit': 4900,
#  'O2_Lambda_Voltage_ER_value': 4900,
#  'O2_Lambda_Voltage_unit': 4900,
#  'O2_Lambda_Voltage_value': 4900,
#  'Rpm_unit': 4900,
#  'Rpm_value': 4900,
#  'Speed_unit': 4900,
#  'Speed_value': 4900,
# ...

# %%
data.tail(10)
# Out:
#       Unnamed: 0 CO2_unit  CO2_value Consumption_unit  Consumption_value  \
# 4890          90      kPa       30.0                c               36.0
# 4891          91      kPa       51.0                c               37.0
# 4892          92      kPa       61.0                c               36.0
# 4893          93      kPa       41.0                c               35.0
# 4894          94      kPa       21.0                c               34.0
# 4895          95      kPa       32.0                c               34.0
# 4896          96      kPa       32.0                c               34.0
# 4897          97      kPa       50.0                c               34.0
# 4898          98      kPa       50.0                c               34.0
# 4899          99      kPa       42.0                c               34.0
#
#      Engine_Load_unit  Engine_Load_value GPS_Accuracy_unit  \
# 4890            u/min             1573.0              km/h
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0 CO2_unit  CO2_value Consumption_unit  Consumption_value  \
# 0           0     kg/h   4.186649              l/h           1.781553
# 1           1     kg/h   5.135379              l/h           2.185268
# 2           2     kg/h   2.912101              l/h           1.239192
# 3           3     kg/h   2.880418              l/h           1.225710
# 4           4     kg/h   2.900948              l/h           1.234446
# 5           5     kg/h  30.476267              l/h          12.968624
# 6           6     kg/h  31.395288              l/h          13.359697
# 7           7     kg/h  17.272646              l/h           7.350062
# 8           8     kg/h   6.551326              l/h           2.787798
# 9           9     kg/h   2.910936              l/h           1.238696
#
#   Engine_Load_unit  Engine_Load_value GPS_Accuracy_unit  GPS_Accuracy_value  \
# 0                %          20.091683                 %             8.00000
# ...
